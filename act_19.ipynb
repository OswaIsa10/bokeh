# %%
from google.colab import files 
files.upload()
# Out:
#      <input type="file" id="files-c7954691-6f4f-40e8-b81a-81e84392f12a" name="files[]" multiple disabled />
#      <output id="result-c7954691-6f4f-40e8-b81a-81e84392f12a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving 3.- Datos Calidad aire CDMX.csv to 3.- Datos Calidad aire CDMX.csv
# ...

# %%
import pandas as pd 
df=pd.read_csv('3.- Datos Calidad aire CDMX.csv')
print(df.head())
# Out:
#         Fecha      Zona Contaminante  Valor Maximo Estacion CategoriaAire  Dias
# 0  2012-01-01  NOROESTE        Ozono            53    Secas       Regular     1
# 1  2012-01-01  NOROESTE   Particulas            89    Secas       Regular     1
# 2  2012-01-01   NORESTE        Ozono            60    Secas       Regular     1
# 3  2012-01-01   NORESTE   Particulas           130    Secas          Mala     1
# 4  2012-01-01    CENTRO        Ozono            55    Secas       Regular     1

# %% [markdown]
#  **Graficas en colab ** *texto en cursiva*

# %%
import matplotlib.pyplot as plt
#import pandas as pd
x=df['Zona']
y=df['Contaminante']
z=df['Valor Maximo']
plt.scatter(x,y,z)
plt.show()
